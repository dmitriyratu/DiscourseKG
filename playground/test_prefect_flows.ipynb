# %% [markdown]
# ## Setup

# %%
from flows.scrape_flow import scrape_flow
from flows.filter_flow import filter_flow
from flows.summarize_flow import summarize_flow
from flows.extract_flow import extract_flow
from flows.categorize_flow import categorize_flow
from flows.graph_flow import graph_flow

import traceback

# %% [markdown]
# ## Step 2: Scrape Flow

# %%
try:
    result = scrape_flow()
    
except Exception as e:
    traceback.print_exc()

# %% [markdown]
# ## Step 3: Filter Flow

# %%
try:
    result = filter_flow()
    
except Exception as e:
    traceback.print_exc()

# %% [markdown]
# ## Step 4: Test Summarize Flow

# %%
try:
    result = summarize_flow()
    
except Exception as e:
    traceback.print_exc()

# %% [markdown]
# ## Step 5: Test Extract Flow

# %%
try:
    result = extract_flow()

except Exception as e:
    traceback.print_exc()

# %% [markdown]
# ## Step 6: Test Categorize Flow

# %%
try:
    result = categorize_flow()
    
except Exception as e:
    traceback.print_exc()
# Out:
# 00:53:44.141 | INFO    | Flow run 'cautious-mule' - Beginning flow run 'cautious-mule' for flow 'categorize-flow'
# 00:53:44.155 | INFO    | Flow run 'cautious-mule' - View at http://127.0.0.1:4200/runs/flow-run/3482442b-9fea-45c7-ae97-4e36300450f6
# 2026-03-03 00:53:44,157 - categorize_flow - INFO - Starting categorize_flow
# 2026-03-03 00:53:44,161 - categorize_flow - INFO - Found 1 items to process for stage PipelineStages.CATEGORIZE
# 2026-03-03 00:53:44,163 - categorize_flow - INFO - Processing item 1/1: interview-tom-llamas-of-nbc-news-intervi_2884f3
# 2026-03-03 00:53:45,680 - categorizer - INFO - Retrying categorization for interview-tom-llamas-of-nbc-news-intervi_2884f3: has_failed_output=False
# 2026-03-03 00:53:45,683 - categorizer - INFO - Chunking interview-tom-llamas-of-nbc-news-intervi_2884f3: 97943 chars -> 18 chunks
# 00:55:37.507 | INFO    | Task run 'categorize_item-5f7' - Task run failed with exception: CategorizationError('2 validation errors for CategorizationOutput\nentities.10.mentions\n  Value error, Duplicate (speaker, topic) pairs found: {(\'trump\', \'defense\')}. Each entity must have ONE mention per (speaker, topic). [type=value_error, input_value=[{\'speaker\': \'trump\', \'to...remely safe place.\']}]}], input_type=list]\n    For further information visit https://errors.pydantic.dev/2.12/v/value_error\nentities.11.mentions\n  Value error, Duplicate (speaker, topic) pairs found: {(\'trump\', \'defense\')}. Each entity must have ONE mention per (speaker, topic). [type=value_error, input_value=[{\'speaker\': \'trump\', \'to... certain sections."]}]}], input_type=list]\n    For further information visit https://errors.pydantic.dev/2.12/v/value_error') - Retry 1/2 will start 10 second(s) from now
# 2026-03-03 00:55:47,524 - categorizer - INFO - Retrying categorization for interview-tom-llamas-of-nbc-news-intervi_2884f3: has_failed_output=False
# 2026-03-03 00:55:47,529 - categorizer - INFO - Chunking interview-tom-llamas-of-nbc-news-intervi_2884f3: 97943 chars -> 18 chunks
# 00:57:01.280 | INFO    | Task run 'categorize_item-5f7' - Task run failed with exception: CategorizationError('1 validation error for CategorizationOutput\nentities.9.mentions\n  Value error, Duplicate (speaker, topic) pairs found: {(\'trump\', \'defense\')}. Each entity must have ONE mention per (speaker, topic). [type=value_error, input_value=[{\'speaker\': \'trump\', \'to...own because of us."]}]}], input_type=list]\n    For further information visit https://errors.pydantic.dev/2.12/v/value_error') - Retry 2/2 will start 10 second(s) from now
# 2026-03-03 00:57:11,292 - categorizer - INFO - Retrying categorization for interview-tom-llamas-of-nbc-news-intervi_2884f3: has_failed_output=False
# 2026-03-03 00:57:11,294 - categorizer - INFO - Chunking interview-tom-llamas-of-nbc-news-intervi_2884f3: 97943 chars -> 18 chunks

# %% [markdown]
# ## Step 7: Test Graph Flow

# %%
try:
    result = graph_flow()
    
except Exception as e:
    traceback.print_exc()
