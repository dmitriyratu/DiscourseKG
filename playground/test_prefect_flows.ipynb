# %% [markdown]
# ## Setup

# %%
from flows.scrape_flow import scrape_flow
from flows.filter_flow import filter_flow
from flows.summarize_flow import summarize_flow
from flows.categorize_flow import categorize_flow
from flows.graph_flow import graph_flow

import traceback

# %% [markdown]
# ## Step 2: Scrape Flow

# %%
try:
    result = scrape_flow()
    
except Exception as e:
    traceback.print_exc()

# %% [markdown]
# ## Step 3: Filter Flow

# %%
try:
    result = filter_flow()
    
except Exception as e:
    traceback.print_exc()

# %% [markdown]
# ## Step 4: Test Summarize Flow

# %%
try:
    result = summarize_flow()
    
except Exception as e:
    traceback.print_exc()

# %% [markdown]
# ## Step 5: Test Categorize Flow

# %%
try:
    result = categorize_flow()
    
except Exception as e:
    traceback.print_exc()
# Out:
# 00:52:29.967 | INFO    | Flow run 'qualified-turkey' - Beginning flow run 'qualified-turkey' for flow 'categorize-flow'
# 00:52:29.981 | INFO    | Flow run 'qualified-turkey' - View at http://127.0.0.1:4200/runs/flow-run/0e0751f6-e64f-46cc-b27f-66a85a91af0e
# 2026-02-23 00:52:29,985 - categorize_flow - INFO - Starting categorize_flow
# 2026-02-23 00:52:29,988 - categorize_flow - INFO - Found 1 items to process for stage PipelineStages.CATEGORIZE
# 2026-02-23 00:52:29,990 - categorize_flow - INFO - Processing item 1/1: interview-tom-llamas-of-nbc-news-intervi_2884f3
# 2026-02-23 00:52:31,547 - categorizer - INFO - Retrying categorization for interview-tom-llamas-of-nbc-news-intervi_2884f3: has_failed_output=False
# 2026-02-23 00:52:49,396 - categorizer - INFO - LLM token usage for interview-tom-llamas-of-nbc-news-intervi_2884f3: {'input_tokens': 32274, 'output_tokens': 833}
# 00:52:49.400 | INFO    | Task run 'categorize_item-059' - Finished in state Completed()
# 2026-02-23 00:52:49,406 - categorize_flow - INFO - Completed categorize_flow for 1 items
# 2026-02-23 00:52:49,406 - categorize_flow - INFO - Completed categorize_flow
# 00:52:49.453 | INFO    | Flow run 'qualified-turkey' - Finished in state Completed()

# %% [markdown]
# ## Step 6: Test Graph Flow

# %%
try:
    result = graph_flow()
    
except Exception as e:
    traceback.print_exc()
