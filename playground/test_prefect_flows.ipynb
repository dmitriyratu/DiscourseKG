# %% [markdown]
# ## Setup

# %%
from flows.scrape_flow import scrape_flow
from flows.filter_flow import filter_flow
from flows.summarize_flow import summarize_flow
from flows.extract_flow import extract_flow
from flows.categorize_flow import categorize_flow
from flows.graph_flow import graph_flow

import traceback

# %% [markdown]
# ## Step 2: Scrape Flow

# %%
try:
    result = scrape_flow()
    
except Exception as e:
    traceback.print_exc()

# %% [markdown]
# ## Step 3: Filter Flow

# %%
try:
    result = filter_flow()
    
except Exception as e:
    traceback.print_exc()

# %% [markdown]
# ## Step 4: Summarize Flow

# %%
try:
    result = summarize_flow()
    
except Exception as e:
    traceback.print_exc()

# %% [markdown]
# ## Step 5: Extract Flow

# %%
try:
    result = extract_flow()

except Exception as e:
    traceback.print_exc()
# Out:
# 20:38:04.444 | INFO    | Flow run 'sophisticated-dingo' - Beginning flow run 'sophisticated-dingo' for flow 'extract-flow'
# 20:38:04.448 | INFO    | Flow run 'sophisticated-dingo' - View at http://127.0.0.1:4200/runs/flow-run/970bb6db-6c22-49a4-bde8-5a8fdf2722ea
# 2026-03-10 20:38:04,451 - extract_flow - INFO - Starting extract_flow
# 2026-03-10 20:38:04,458 - extract_flow - INFO - Found 1 items to process for stage PipelineStages.EXTRACT
# 2026-03-10 20:38:04,462 - extract_flow - INFO - Processing item 1/1: interview-tom-llamas-of-nbc-news-intervi_2884f3
# 2026-03-10 20:38:04,511 - extractor - INFO - Phase 1 starting for interview-tom-llamas-of-nbc-news-intervi_2884f3
# 2026-03-10 20:38:07,333 - extractor - INFO - Phase 1 complete — 13 entities across 1 speakers for interview-tom-llamas-of-nbc-news-intervi_2884f3
# 2026-03-10 20:38:07,336 - extractor - INFO - Phase 2 starting for interview-tom-llamas-of-nbc-news-intervi_2884f3 (5 chunks, 97943 chars)
# ...

# %% [markdown]
# ## Step 6: Categorize Flow

# %%
try:
    result = categorize_flow()
    
except Exception as e:
    traceback.print_exc()

# %% [markdown]
# ## Step 7: Graph Flow

# %%
try:
    result = graph_flow()
    
except Exception as e:
    traceback.print_exc()
