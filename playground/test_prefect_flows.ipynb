# %% [markdown]
# ## Setup

# %%
from flows.discover_flow import discover_flow
from flows.scrape_flow import scrape_flow
from flows.summarize_flow import summarize_flow
from flows.categorize_flow import categorize_flow
from flows.graph_flow import graph_flow

import traceback

# %% [markdown]
# ## Step 1: Test DiscoverFlow

# %%
# Test DiscoverFlow

try:
    result = discover_flow( 
        speaker="test_speaker",
        start_date="2025-01-01", 
        end_date="2025-01-02"
    )
    
except Exception as e:
    traceback.print_exc()
# Out:
# 02:31:56.834 | INFO    | Flow run 'finicky-shark' - Beginning flow run 'finicky-shark' for flow 'discover-flow'
# 02:31:56.842 | INFO    | Flow run 'finicky-shark' - View at http://127.0.0.1:4200/runs/flow-run/7eeb2e08-0629-40fa-b8b4-49cd32323062
# 2025-11-22 02:31:56,844 - discover_flow - INFO - Starting discover_flow for test_speaker from 2025-01-01 to 2025-01-02
# 2025-11-22 02:31:56,886 - DiscoverEndpoint - INFO - Processing discovery request for speaker: test_speaker
# 02:31:56.895 | INFO    | Task run 'discover_content-4d6' - Finished in state Completed()
# 2025-11-22 02:31:56,899 - discover_flow - INFO - Discovery complete - created 0 pipeline states
# 02:31:56.939 | INFO    | Flow run 'finicky-shark' - Finished in state Completed()

# %% [markdown]
# ## Step 2: Test ScrapeFlow

# %%
# Test ScrapeFlow

try:
    result = scrape_flow()
    
except Exception as e:
    traceback.print_exc()
# Out:
# 02:31:58.006 | INFO    | Flow run 'jolly-hawk' - Beginning flow run 'jolly-hawk' for flow 'scrape-flow'
# 02:31:58.009 | INFO    | Flow run 'jolly-hawk' - View at http://127.0.0.1:4200/runs/flow-run/d586896c-1e62-4a66-baa8-902eb9eee6df
# 2025-11-22 02:31:58,011 - scrape_flow - INFO - Starting scrape_flow
# 2025-11-22 02:31:58,023 - scrape_flow - INFO - Found 3 items to process for stage scrape
# 2025-11-22 02:31:58,025 - scrape_flow - INFO - Processing item 1/3: discovered-item-0-20251122_023156
# 02:31:58.058 | INFO    | Task run 'scrape_item-af9' - Finished in state Completed()
# 2025-11-22 02:31:58,090 - scrape_flow - INFO - Processing item 2/3: discovered-item-1-20251122_023156
# 02:31:58.116 | INFO    | Task run 'scrape_item-fb1' - Finished in state Completed()
# 2025-11-22 02:31:58,149 - scrape_flow - INFO - Processing item 3/3: discovered-item-2-20251122_023156
# 02:31:58.176 | INFO    | Task run 'scrape_item-a34' - Finished in state Completed()
# 2025-11-22 02:31:58,208 - scrape_flow - INFO - Completed scrape_flow for 3 items
# 2025-11-22 02:31:58,209 - scrape_flow - INFO - Completed scrape_flow
# 02:31:58.228 | INFO    | Flow run 'jolly-hawk' - Finished in state Completed()

# %% [markdown]
# ## Step 3: Test SummarizeFlow

# %%
# Test SummarizeFlow

try:
    result = summarize_flow()
    
except Exception as e:
    traceback.print_exc()
# Out:
# 02:32:16.381 | INFO    | Flow run 'interesting-chameleon' - Beginning flow run 'interesting-chameleon' for flow 'summarize-flow'
# 02:32:16.383 | INFO    | Flow run 'interesting-chameleon' - View at http://127.0.0.1:4200/runs/flow-run/be27eb64-f1b7-4035-8b9b-953bd33b1b04
# 2025-11-22 02:32:16,384 - summarize_flow - INFO - Starting summarize_flow
# 2025-11-22 02:32:16,399 - summarize_flow - INFO - Found 3 items to process for stage summarize
# 2025-11-22 02:32:16,401 - summarize_flow - INFO - Processing item 1/3: discovered-item-0-20251122_023156
# 02:32:18.352 | INFO    | Task run 'summarize_item-b77' - Finished in state Completed()
# 2025-11-22 02:32:18,363 - summarize_flow - INFO - Processing item 2/3: discovered-item-1-20251122_023156
# 02:32:19.921 | INFO    | Task run 'summarize_item-786' - Finished in state Completed()
# 2025-11-22 02:32:19,945 - summarize_flow - INFO - Processing item 3/3: discovered-item-2-20251122_023156
# 02:32:22.088 | INFO    | Task run 'summarize_item-d93' - Finished in state Completed()
# 2025-11-22 02:32:22,114 - summarize_flow - INFO - Completed summarize_flow for 3 items
# 2025-11-22 02:32:22,116 - summarize_flow - INFO - Completed summarize_flow
# 02:32:22.171 | INFO    | Flow run 'interesting-chameleon' - Finished in state Completed()

# %% [markdown]
# ## Step 4: Test CategorizeFlow

# %%
# Test CategorizeFlow

try:
    result = categorize_flow()
    
except Exception as e:
    traceback.print_exc()
# Out:
# 02:32:22.496 | INFO    | Flow run 'enigmatic-pony' - Beginning flow run 'enigmatic-pony' for flow 'categorize-flow'
# 02:32:22.498 | INFO    | Flow run 'enigmatic-pony' - View at http://127.0.0.1:4200/runs/flow-run/43bda6e1-8774-4f99-a4a9-2aef39371acb
# 2025-11-22 02:32:22,499 - categorize_flow - INFO - Starting categorize_flow
# 2025-11-22 02:32:22,512 - categorize_flow - INFO - Found 3 items to process for stage categorize
# 2025-11-22 02:32:22,513 - categorize_flow - INFO - Processing item 1/3: discovered-item-0-20251122_023156
# 2025-11-22 02:32:43,693 - categorizer - INFO - LLM token usage for discovered-item-0-20251122_023156: {'input_tokens': 2469, 'output_tokens': 1050}
# 02:32:43.699 | INFO    | Task run 'categorize_item-f41' - Finished in state Completed()
# 2025-11-22 02:32:43,718 - categorize_flow - INFO - Processing item 2/3: discovered-item-1-20251122_023156
# 2025-11-22 02:33:01,236 - categorizer - INFO - LLM token usage for discovered-item-1-20251122_023156: {'input_tokens': 2469, 'output_tokens': 858}
# 02:33:01.239 | INFO    | Task run 'categorize_item-e21' - Finished in state Completed()
# 2025-11-22 02:33:01,261 - categorize_flow - INFO - Processing item 3/3: discovered-item-2-20251122_023156
# 2025-11-22 02:33:23,656 - categorizer - INFO - LLM token usage for discovered-item-2-20251122_023156: {'input_tokens': 2484, 'output_tokens': 1038}
# 02:33:23.660 | INFO    | Task run 'categorize_item-d7b' - Finished in state Completed()
# 2025-11-22 02:33:23,681 - categorize_flow - INFO - Completed categorize_flow for 3 items
# 2025-11-22 02:33:23,682 - categorize_flow - INFO - Completed categorize_flow
# 02:33:23.717 | INFO    | Flow run 'enigmatic-pony' - Finished in state Completed()

# %% [markdown]
# ## Step 5: Test GraphFlow

# %%
# Test GraphFlow

try:
    result = graph_flow()
    
except Exception as e:
    traceback.print_exc()
# Out:
# 02:34:45.300 | INFO    | Flow run 'brown-hornet' - Beginning flow run 'brown-hornet' for flow 'graph-flow'
# 02:34:45.302 | INFO    | Flow run 'brown-hornet' - View at http://127.0.0.1:4200/runs/flow-run/f41e30f6-2bd8-417e-9f66-8a72a97428e6
# 2025-11-22 02:34:45,303 - graph_flow - INFO - Starting graph_flow
# 2025-11-22 02:34:45,304 - graph_flow - INFO - Found 3 items to process for stage graph
# 2025-11-22 02:34:45,305 - graph_flow - INFO - Processing item 1/3: discovered-item-0-20251122_023156
# 2025-11-22 02:34:45,526 - grapher - INFO - Successfully loaded discovered-item-0-20251122_023156 to Neo4j: {'nodes_created': 29, 'relationships_created': 28}
# 02:34:45.530 | INFO    | Task run 'graph_item-291' - Finished in state Completed()
# 2025-11-22 02:34:45,536 - graph_flow - INFO - Processing item 2/3: discovered-item-1-20251122_023156
# 2025-11-22 02:34:45,688 - grapher - INFO - Successfully loaded discovered-item-1-20251122_023156 to Neo4j: {'nodes_created': 18, 'relationships_created': 21}
# 02:34:45.691 | INFO    | Task run 'graph_item-746' - Finished in state Completed()
# 2025-11-22 02:34:45,709 - graph_flow - INFO - Processing item 3/3: discovered-item-2-20251122_023156
# 2025-11-22 02:34:45,842 - grapher - INFO - Successfully loaded discovered-item-2-20251122_023156 to Neo4j: {'nodes_created': 21, 'relationships_created': 24}
# 02:34:45.845 | INFO    | Task run 'graph_item-73d' - Finished in state Completed()
# 2025-11-22 02:34:45,865 - graph_flow - INFO - Completed graph_flow for 3 items
# 2025-11-22 02:34:45,866 - graph_flow - INFO - Completed graph_flow
# 02:34:45.886 | INFO    | Flow run 'brown-hornet' - Finished in state Completed()
