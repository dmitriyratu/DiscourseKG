# %% [markdown]
# ## Setup

# %%
from flows.scrape_flow import scrape_flow
from flows.filter_flow import filter_flow
from flows.summarize_flow import summarize_flow
from flows.categorize_flow import categorize_flow
from flows.graph_flow import graph_flow

import traceback

# %% [markdown]
# ## Step 2: Scrape Flow

# %%
try:
    result = scrape_flow()
    
except Exception as e:
    traceback.print_exc()
# Out:
# 18:17:09.993 | INFO    | Flow run 'vague-ammonite' - Beginning flow run 'vague-ammonite' for flow 'scrape-flow'
# 18:17:10.002 | INFO    | Flow run 'vague-ammonite' - View at http://127.0.0.1:4200/runs/flow-run/8de706bd-0161-47eb-a141-d759455e5b33
# 2026-02-22 18:17:10,006 - scrape_flow - INFO - Starting scrape_flow
# 2026-02-22 18:17:10,008 - scrape_flow - INFO - Found 1 items to process for stage PipelineStages.SCRAPE
# 2026-02-22 18:17:10,010 - scrape_flow - INFO - Processing item 1/1: interview-tom-llamas-of-nbc-news-intervi_2884f3

# %% [markdown]
# ## Step 3: Filter Flow

# %%
try:
    result = filter_flow()
    
except Exception as e:
    traceback.print_exc()

# %% [markdown]
# ## Step 4: Test Summarize Flow

# %%
try:
    result = summarize_flow()
    
except Exception as e:
    traceback.print_exc()

# %% [markdown]
# ## Step 5: Test Categorize Flow

# %%
try:
    result = categorize_flow()
    
except Exception as e:
    traceback.print_exc()

# %% [markdown]
# ## Step 6: Test Graph Flow

# %%
try:
    result = graph_flow()
    
except Exception as e:
    traceback.print_exc()
