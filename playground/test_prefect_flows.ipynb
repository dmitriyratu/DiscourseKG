# %% [markdown]
# ## Setup

# %%
from flows.scrape_flow import scrape_flow
from flows.filter_flow import filter_flow
from flows.summarize_flow import summarize_flow
from flows.categorize_flow import categorize_flow
from flows.graph_flow import graph_flow

import traceback

# %% [markdown]
# ## Step 2: Scrape Flow

# %%
try:
    result = scrape_flow()
    
except Exception as e:
    traceback.print_exc()
# Out:
# 20:18:31.414 | INFO    | Flow run 'grinning-kagu' - Beginning flow run 'grinning-kagu' for flow 'scrape-flow'
# 20:18:31.417 | INFO    | Flow run 'grinning-kagu' - View at http://127.0.0.1:4200/runs/flow-run/28655744-ac15-4725-ae08-3cc3e3908c4c
# 2026-03-02 20:18:31,419 - scrape_flow - INFO - Starting scrape_flow
# 2026-03-02 20:18:31,425 - scrape_flow - INFO - Found 1 items to process for stage PipelineStages.SCRAPE
# 2026-03-02 20:18:31,434 - scrape_flow - INFO - Processing item 1/1: interview-tom-llamas-of-nbc-news-intervi_2884f3
# 20:18:48.609 | INFO    | Task run 'scrape_item-a6f' - Finished in state Completed()
# 2026-03-02 20:18:48,626 - scrape_flow - INFO - Completed scrape_flow for 1 items
# 2026-03-02 20:18:48,626 - scrape_flow - INFO - Completed scrape_flow
# 20:18:48.650 | INFO    | Flow run 'grinning-kagu' - Finished in state Completed()

# %% [markdown]
# ## Step 3: Filter Flow

# %%
try:
    result = filter_flow()
    
except Exception as e:
    traceback.print_exc()
# Out:
# 20:21:19.485 | INFO    | Flow run 'ambrosial-bustard' - Beginning flow run 'ambrosial-bustard' for flow 'filter-flow'
# 20:21:19.493 | INFO    | Flow run 'ambrosial-bustard' - View at http://127.0.0.1:4200/runs/flow-run/19c3f554-f056-4133-a46a-daf8e2d02c9f
# 2026-03-02 20:21:19,493 - filter_flow - INFO - Starting filter_flow
# 2026-03-02 20:21:19,493 - filter_flow - INFO - Found 1 items to process for stage PipelineStages.FILTER
# 2026-03-02 20:21:19,502 - filter_flow - INFO - Processing item 1/1: interview-tom-llamas-of-nbc-news-intervi_2884f3
# 2026-03-02 20:21:21,015 - filterer - INFO - Filter token usage for interview-tom-llamas-of-nbc-news-intervi_2884f3: {'input_tokens': 10152, 'output_tokens': 41}
# 20:21:21.018 | INFO    | Task run 'filter_item-9a5' - Finished in state Completed()
# 2026-03-02 20:21:21,031 - filter_flow - INFO - Completed filter_flow for 1 items
# 2026-03-02 20:21:21,031 - filter_flow - INFO - Completed filter_flow
# 20:21:21.056 | INFO    | Flow run 'ambrosial-bustard' - Finished in state Completed()

# %% [markdown]
# ## Step 4: Test Summarize Flow

# %%
try:
    result = summarize_flow()
    
except Exception as e:
    traceback.print_exc()
# Out:
# 20:31:25.066 | INFO    | Flow run 'fortunate-perch' - Beginning flow run 'fortunate-perch' for flow 'summarize-flow'
# 20:31:25.066 | INFO    | Flow run 'fortunate-perch' - View at http://127.0.0.1:4200/runs/flow-run/7fa3471c-a476-47fe-9e98-fb693432a8d7
# 2026-03-02 20:31:25,066 - summarize_flow - INFO - Starting summarize_flow
# 2026-03-02 20:31:25,096 - summarize_flow - INFO - Found 1 items to process for stage PipelineStages.SUMMARIZE
# 2026-03-02 20:31:25,102 - summarize_flow - INFO - Processing item 1/1: interview-tom-llamas-of-nbc-news-intervi_2884f3
# 20:31:59.054 | INFO    | Task run 'summarize_item-bbd' - Finished in state Completed()
# 2026-03-02 20:31:59,081 - summarize_flow - INFO - Completed summarize_flow for 1 items
# 2026-03-02 20:31:59,083 - summarize_flow - INFO - Completed summarize_flow
# 20:31:59.157 | INFO    | Flow run 'fortunate-perch' - Finished in state Completed()

# %% [markdown]
# ## Step 5: Test Categorize Flow

# %%
try:
    result = categorize_flow()
    
except Exception as e:
    traceback.print_exc()
# Out:
# 20:32:25.027 | INFO    | Flow run 'cyber-caterpillar' - Beginning flow run 'cyber-caterpillar' for flow 'categorize-flow'
# 20:32:25.029 | INFO    | Flow run 'cyber-caterpillar' - View at http://127.0.0.1:4200/runs/flow-run/27a6a419-fac4-4903-8869-91ba29298a09
# 2026-03-02 20:32:25,032 - categorize_flow - INFO - Starting categorize_flow
# 2026-03-02 20:32:25,056 - categorize_flow - INFO - Found 1 items to process for stage PipelineStages.CATEGORIZE
# 2026-03-02 20:32:25,061 - categorize_flow - INFO - Processing item 1/1: interview-tom-llamas-of-nbc-news-intervi_2884f3

# %% [markdown]
# ## Step 6: Test Graph Flow

# %%
try:
    result = graph_flow()
    
except Exception as e:
    traceback.print_exc()
