# %% [markdown]
# ## Setup

# %%
from flows.scrape_flow import scrape_flow
from flows.filter_flow import filter_flow
from flows.summarize_flow import summarize_flow
from flows.extract_flow import extract_flow
from flows.categorize_flow import categorize_flow
from flows.graph_flow import graph_flow

import traceback

# %% [markdown]
# ## Step 2: Scrape Flow

# %%
try:
    result = scrape_flow()
    
except Exception as e:
    traceback.print_exc()
# Out:
# 08:59:08.281 | INFO    | Flow run 'wooden-collie' - Beginning flow run 'wooden-collie' for flow 'scrape-flow'
# 08:59:08.295 | INFO    | Flow run 'wooden-collie' - View at http://127.0.0.1:4200/runs/flow-run/e19659f1-4299-4431-81b4-43da2099c080
# 2026-03-12 08:59:08,301 - scrape_flow - INFO - Starting scrape_flow
# 2026-03-12 08:59:08,309 - scrape_flow - INFO - Found 1 items to process for stage PipelineStages.SCRAPE
# 2026-03-12 08:59:08,309 - scrape_flow - INFO - Processing item 1/1: interview-tom-llamas-of-nbc-news-intervi_2884f3
# 2026-03-12 08:59:12,680 - extractor_manager - INFO - Generating extractor for URL: https://rollcall.com/factbase/trump/transcript/donald-trump-interview-tom-llamas-nbc-news-february-4-2026/
# 2026-03-12 08:59:29,606 - extractor_manager - INFO - Sample HTML length: 30000 characters out of 5360719 characters
# 2026-03-12 08:59:37,800 - extractor_manager - INFO - Extractor code generated and validated successfully
# 2026-03-12 08:59:37,803 - extractor_manager - INFO - Saved extractor: c:\Users\dmitr\Projects\DiscourseKG\src\scrape\domains\rollcall_transcript.py
# 08:59:51.480 | INFO    | Task run 'scrape_item-081' - Finished in state Completed()
# 2026-03-12 08:59:51,496 - scrape_flow - INFO - Completed scrape_flow for 1 items
# 2026-03-12 08:59:51,496 - scrape_flow - INFO - Completed scrape_flow
# 08:59:51.537 | INFO    | Flow run 'wooden-collie' - Finished in state Completed()

# %% [markdown]
# ## Step 3: Filter Flow

# %%
try:
    result = filter_flow()
    
except Exception as e:
    traceback.print_exc()
# Out:
# 09:00:26.210 | INFO    | Flow run 'helpful-donkey' - Beginning flow run 'helpful-donkey' for flow 'filter-flow'
# 09:00:26.211 | INFO    | Flow run 'helpful-donkey' - View at http://127.0.0.1:4200/runs/flow-run/0c50896d-727a-4689-b499-67d126c570b6
# 2026-03-12 09:00:26,217 - filter_flow - INFO - Starting filter_flow
# 2026-03-12 09:00:26,224 - filter_flow - INFO - Found 1 items to process for stage PipelineStages.FILTER
# 2026-03-12 09:00:26,224 - filter_flow - INFO - Processing item 1/1: interview-tom-llamas-of-nbc-news-intervi_2884f3
# 2026-03-12 09:00:33,533 - filterer - INFO - Filter token usage for interview-tom-llamas-of-nbc-news-intervi_2884f3: input_tokens=10200 output_tokens=53
# 09:00:33.543 | INFO    | Task run 'filter_item-0eb' - Finished in state Completed()
# 2026-03-12 09:00:33,562 - filter_flow - INFO - Completed filter_flow for 1 items
# 2026-03-12 09:00:33,564 - filter_flow - INFO - Completed filter_flow
# 09:00:33.611 | INFO    | Flow run 'helpful-donkey' - Finished in state Completed()

# %% [markdown]
# ## Step 4: Summarize Flow

# %%
try:
    result = summarize_flow()
    
except Exception as e:
    traceback.print_exc()
# Out:
# 09:00:34.203 | INFO    | Flow run 'keen-polecat' - Beginning flow run 'keen-polecat' for flow 'summarize-flow'
# 09:00:34.214 | INFO    | Flow run 'keen-polecat' - View at http://127.0.0.1:4200/runs/flow-run/79664c99-7343-4f99-a961-7e5a0cf05041
# 2026-03-12 09:00:34,214 - summarize_flow - INFO - Starting summarize_flow
# 2026-03-12 09:00:34,214 - summarize_flow - INFO - Found 1 items to process for stage PipelineStages.SUMMARIZE
# 2026-03-12 09:00:34,224 - summarize_flow - INFO - Processing item 1/1: interview-tom-llamas-of-nbc-news-intervi_2884f3
# 09:01:10.932 | INFO    | Task run 'summarize_item-0ad' - Finished in state Completed()
# 2026-03-12 09:01:10,951 - summarize_flow - INFO - Completed summarize_flow for 1 items
# 2026-03-12 09:01:10,952 - summarize_flow - INFO - Completed summarize_flow
# 09:01:11.010 | INFO    | Flow run 'keen-polecat' - Finished in state Completed()

# %% [markdown]
# ## Step 5: Extract Flow

# %%
try:
    result = extract_flow()

except Exception as e:
    traceback.print_exc()
# Out:
# 09:01:11.581 | INFO    | Flow run 'stereotyped-lori' - Beginning flow run 'stereotyped-lori' for flow 'extract-flow'
# 09:01:11.585 | INFO    | Flow run 'stereotyped-lori' - View at http://127.0.0.1:4200/runs/flow-run/9d02aecd-37fa-4098-99a2-a5e9aaf9f5a1
# 2026-03-12 09:01:11,587 - extract_flow - INFO - Starting extract_flow
# 2026-03-12 09:01:11,593 - extract_flow - INFO - Found 1 items to process for stage PipelineStages.EXTRACT
# 2026-03-12 09:01:11,597 - extract_flow - INFO - Processing item 1/1: interview-tom-llamas-of-nbc-news-intervi_2884f3
# 2026-03-12 09:01:11,670 - extractor - INFO - Phase 1 starting for interview-tom-llamas-of-nbc-news-intervi_2884f3
# 2026-03-12 09:01:23,485 - extractor - INFO - Phase 1 complete — 23 entities across 1 speakers for interview-tom-llamas-of-nbc-news-intervi_2884f3
# 2026-03-12 09:01:23,488 - extractor - INFO - Phase 2 starting for interview-tom-llamas-of-nbc-news-intervi_2884f3 (11 chunks, 102048 chars)
# 2026-03-12 09:02:07,040 - extractor - INFO - Phase 2 complete — 27 passages across 1 speakers for interview-tom-llamas-of-nbc-news-intervi_2884f3
# 09:02:07.042 | INFO    | Task run 'extract_item-6e3' - Finished in state Completed()
# 2026-03-12 09:02:07,061 - extract_flow - INFO - Completed extract_flow for 1 items
# 2026-03-12 09:02:07,065 - extract_flow - INFO - Completed extract_flow
# 09:02:07.112 | INFO    | Flow run 'stereotyped-lori' - Finished in state Completed()

# %% [markdown]
# ## Step 6: Categorize Flow

# %%
try:
    result = categorize_flow()
    
except Exception as e:
    traceback.print_exc()
# Out:
# 09:02:07.695 | INFO    | Flow run 'hungry-snail' - Beginning flow run 'hungry-snail' for flow 'categorize-flow'
# 09:02:07.696 | INFO    | Flow run 'hungry-snail' - View at http://127.0.0.1:4200/runs/flow-run/28f05c76-a05e-4c77-8896-8acb440b2290
# 2026-03-12 09:02:07,696 - categorize_flow - INFO - Starting categorize_flow
# 2026-03-12 09:02:07,707 - categorize_flow - INFO - Found 1 items to process for stage PipelineStages.CATEGORIZE
# 2026-03-12 09:02:07,710 - categorize_flow - INFO - Processing item 1/1: interview-tom-llamas-of-nbc-news-intervi_2884f3
# 09:04:05.350 | INFO    | Task run 'categorize_item-bad' - Finished in state Completed()
# 2026-03-12 09:04:05,375 - categorize_flow - INFO - Completed categorize_flow for 1 items
# 2026-03-12 09:04:05,376 - categorize_flow - INFO - Completed categorize_flow
# 09:04:05.438 | INFO    | Flow run 'hungry-snail' - Finished in state Completed()

# %% [markdown]
# ## Step 7: Graph Flow

# %%
try:
    result = graph_flow()
    
except Exception as e:
    traceback.print_exc()
